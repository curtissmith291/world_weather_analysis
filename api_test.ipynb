# %%
apiKey = "f1d7a10c77d1487312da7466b64c599f"

austin = f"http://api.openweathermap.org/data/2.5/weather?q=austin&appid={apiKey}"

exampleCall = f"http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={apiKey}"



import requests
from pprint import pprint
response = requests.get(austin)
pprint(response.status_code)
pprint(response.json())
# Out:
# 200
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 30.2672, 'lon': -97.7431},
#  'dt': 1621902397,
#  'id': 4671654,
#  'main': {'feels_like': 297.1,
#           'humidity': 88,
#           'pressure': 1014,
#           'temp': 296.42,
#           'temp_max': 299.34,
#           'temp_min': 294.42},
#  'name': 'Austin',
#  'sys': {'country': 'US',
#          'id': 2006840,
#          'sunrise': 1621855944,
#          'sunset': 1621905817,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 68, 'gust': 3.58, 'speed': 1.34}}

# %%
nytAPIkey = "JcvP50pGzyo3whYjKHX9V99HQLp6oP8G"

exampleCall = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key={nytAPIkey}"

response = requests.get(exampleCall)
pprint(response.status_code)
pprint(response.json())
# Out:
# 200
# {'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights '
#               'Reserved.',
#  'response': {'docs': [{'_id': 'nyt://article/b4562bec-a820-5839-9f6b-b62b99937a56',
#                         'abstract': 'A delay is said to have stemmed from an '
#                                     'initial threat by former President Donald '
#                                     'J. Trump to intervene, but he apparently '
#                                     'reversed course.',
#                         'byline': {'organization': None,
#                                    'original': 'By Charlie Savage',
#                                    'person': [{'firstname': 'Charlie',
#                                                'lastname': 'Savage',
#                                                'middlename': None,
#                                                'organization': '',
#                                                'qualifier': None,
# ...

# %%
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f1d7a10c77d1487312da7466b64c599f

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f1d7a10c77d1487312da7466b64c599f&q=Boston

# %%
resp = requests.get(city_url)
weather_json = resp.json()
print(weather_json.keys())
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
weather_json.get("main")
# Out:
# {'temp': 63.73,
#  'feels_like': 63.05,
#  'temp_min': 56.95,
#  'temp_max': 71.17,
#  'pressure': 1018,
#  'humidity': 69}

# %%
weather_json.status_code
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-2c0445285236> in <module>
# ----> 1 weather_json.status_code
#
# AttributeError: 'dict' object has no attribute 'status_code'

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 63.57,
#   'feels_like': 62.92,
#   'temp_min': 56.95,
#   'temp_max': 71.17,
#   'pressure': 1018,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 8.01, 'deg': 278, 'gust': 18.01},
#  'clouds': {'all': 75},
#  'dt': 1621995908,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1621934050,
#   'sunset': 1621987715},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
    city_weather.json()
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
boston_data = city_weather.json()
boston_data["sys"]["country"]
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 95.68 48 31 8.99

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-05-26 17:57:33'
